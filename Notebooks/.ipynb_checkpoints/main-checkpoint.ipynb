# %%
import sys
import os    
import argparse


# Add the root directory to the Python path
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
if root_dir not in sys.path:
    sys.path.append(root_dir)

# %%
# %matplotlib inline

# Import necessary libraries
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from main import main

# %%
# Define the parameters
args = argparse.Namespace(
                dataset="sine",
                noise_var=0.006,
                training_config_section="PREDICTION_TRAINING",
                learning_rate=None,
                num_epochs=60,
                train_seq_len=100,
                test_seq_len=50,
                train_batch_size=32,
                val_batch_size=8,
                pred_batch_size=32,
                models=["DKF", "AR_DKF", "FAR_DKF"],
                normalization_type="standardize",
                per_feature=False,
                per_sequence=False,
                normalization_range=None,
                lorenz_points=11000,
                lorenz_initial_point=[2, 1, 1],
                lorenz_range=[8600, 10500],
                loss_function="weighted_mse",
                enable_animation=False,
                show_eval=True,
                generate_latex=False
            )

# %%
# Call the main function with the parameters
main(args)
# Out:
# ==============================================
# Training and evaluating model: DKF
# poch 60/60 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 83.32it/s]
# ==============================================
# Training and evaluating model: AR_DKF
# poch 60/60 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 82.72it/s]
# ==============================================
# Training and evaluating model: FAR_DKF
# poch 60/60 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19/19 [00:00<00:00, 64.46it/s]
# Model: DKF
#   MSE of the noise: 0.005988335236907005
#   MSE of the reconstruction: 0.005790685303509235
#   MSE of the prediction: 0.922003448009491
#   Standard deviation of the MSE of the prediction: 1.0884294509887695
# Model: AR_DKF
#   MSE of the noise: 0.005988335236907005
#   MSE of the reconstruction: 0.005827358458191156
#   MSE of the prediction: 0.00810422282665968
#   Standard deviation of the MSE of the prediction: 0.01185979600995779
# Model: FAR_DKF
#   MSE of the noise: 0.005988335236907005
#   MSE of the reconstruction: 0.005711127072572708
#   MSE of the prediction: 0.008621769957244396
#   Standard deviation of the MSE of the prediction: 0.012879115529358387

# %%
# Define the parameters
args = argparse.Namespace(
                dataset="lorenz",
                noise_var=0.006,
                training_config_section="PREDICTION_TRAINING",
                learning_rate=None,
                num_epochs=120,
                train_seq_len=100,
                test_seq_len=50,
                train_batch_size=32,
                val_batch_size=8,
                pred_batch_size=32,
                models=["DKF", "AR_DKF", "FAR_DKF"],
                normalization_type="standardize",
                per_feature=False,
                per_sequence=False,
                normalization_range=None,
                lorenz_points=11000,
                lorenz_initial_point=[2, 1, 1],
                lorenz_range=[8600, 10500],
                loss_function="weighted_mse",
                enable_animation=False,
                show_eval=True,
                generate_latex=False
            )

# %%
# Call the main function with the parameters
main(args)
# Out:
# ==============================================
# Training and evaluating model: DKF
# poch 120/120 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 77.02it/s]
# ==============================================
# Training and evaluating model: AR_DKF
# poch 120/120 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 81.33it/s]
# ==============================================
# Training and evaluating model: FAR_DKF
# poch 120/120 (Validation): 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 69.14it/s]
# Model: DKF
#   MSE of the noise: 0.006037531886249781
#   MSE of the reconstruction: 0.006009608507156372
#   MSE of the prediction: 0.1276313215494156
#   Standard deviation of the MSE of the prediction: 0.24181807041168213
# Model: AR_DKF
#   MSE of the noise: 0.006037531886249781
#   MSE of the reconstruction: 0.005990953650325537
#   MSE of the prediction: 0.010002058930695057
#   Standard deviation of the MSE of the prediction: 0.0148161007091403
# Model: FAR_DKF
#   MSE of the noise: 0.006037531886249781
#   MSE of the reconstruction: 0.005806052591651678
#   MSE of the prediction: 0.010612613521516323
#   Standard deviation of the MSE of the prediction: 0.016806671395897865
